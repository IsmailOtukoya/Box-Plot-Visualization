# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
from matplotlib.ticker import MaxNLocator

# %%
df = pd.read_csv(r"C:\Users\ISMAIL\Downloads\archive (4)\IT Salary Survey EU  2020.csv")
df
# Out:
#                 Timestamp   Age Gender         City  \
# 0     24/11/2020 11:14:15  26.0   Male       Munich
# 1     24/11/2020 11:14:16  26.0   Male       Berlin
# 2     24/11/2020 11:14:21  29.0   Male       Berlin
# 3     24/11/2020 11:15:24  28.0   Male       Berlin
# 4     24/11/2020 11:15:46  37.0   Male       Berlin
# ...                   ...   ...    ...          ...
# 1248  18/01/2021 15:05:50  31.0   Male       Berlin
# 1249  18/01/2021 17:46:02  33.0   Male       Berlin
# 1250  18/01/2021 23:20:35  39.0   Male       Munich
# 1251  19/01/2021 10:17:58  26.0   Male  Saarbrücken
# 1252  19/01/2021 12:01:11  26.0   Male       Berlin
#
#                                    Position  Total years of experience  \
# 0                          Software Engineer                         5
# 1                          Backend Developer                         7
# 2                          Software Engineer                        12
# 3                         Frontend Developer                         4
# 4                          Backend Developer                        17
# ...                                      ...                       ...
# 1248                       Backend Developer                         9
# 1249  Researcher/ Consumer Insights Analyst                         10
# 1250                   IT Operations Manager                        15
# 1251                      Frontend Developer                         7
# 1252                                  DevOps                         2
#
#      Years of experience in Germany Seniority level  \
# 0                                 3          Senior
# 1                                 4          Senior
# 2                                 6            Lead
# 3                                 1          Junior
# 4                                 6          Senior
# ...                             ...             ...
# 1248                              5          Senior
# 1249                            1.5          Senior
# 1250                              2            Lead
# 1251                              7          Middle
# 1252                              2          Middle
#
#      Your main technology / programming language  \
# 0                                     TypeScript
# 1                                           Ruby
# 2                        Javascript / Typescript
# 3                                     Javascript
# 4                                        C# .NET
# ...                                          ...
# 1248                                        Java
# 1249                           consumer analysis
# 1250                                         PHP
# 1251                                  JavaScript
# 1252                                        yaml
#
#      Other technologies/programming languages you use often  ...  \
# 0                       Kotlin, Javascript / Typescript      ...
# 1                                                   NaN      ...
# 2                       Javascript / Typescript, Docker      ...
# 3                                                   NaN      ...
# 4                                .NET, SQL, AWS, Docker      ...
# ...                                                 ...      ...
# 1248  Python, Javascript / Typescript, Java / Scala,...      ...
# 1249                                                NaN      ...
# 1250  Python, C/C++, Javascript / Typescript, Java /...      ...
# 1251  Javascript / Typescript, Docker, HTML, CSS; Ad...      ...
# 1252  Python, AWS, Kubernetes, Docker, terraform, an...      ...
#
#       Annual bonus+stocks one year ago. Only answer if staying in same country  \
# 0                                                 10000
# 1                                                  5000
# 2                                                100000
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1248                                              72000
# 1249                                               2500
# 1250                                                NaN
# 1251                                              36400
# 1252                                                  0
#
#      Number of vacation days           Employment status   Сontract duration  \
# 0                         30          Full-time employee  Unlimited contract
# 1                         28          Full-time employee  Unlimited contract
# 2                         30  Self-employed (freelancer)  Temporary contract
# 3                         24          Full-time employee  Unlimited contract
# 4                         29          Full-time employee  Unlimited contract
# ...                      ...                         ...                 ...
# 1248                      26          Full-time employee  Unlimited contract
# 1249              unlimited           Full-time employee  Unlimited contract
# 1250                      28          Full-time employee  Unlimited contract
# 1251                      27          Full-time employee  Unlimited contract
# 1252                      30          Full-time employee  Unlimited contract
#
#      Main language at work Company size Company type  \
# 0                  English       51-100      Product
# 1                  English     101-1000      Product
# 2                  English     101-1000      Product
# 3                  English       51-100      Startup
# 4                  English     101-1000      Product
# ...                    ...          ...          ...
# 1248               English       51-100      Product
# 1249               English        1000+      Product
# 1250               English     101-1000    eCommerce
# 1251                German     101-1000      Product
# 1252               English       51-100      Startup
#
#      Have you lost your job due to the coronavirus outbreak?  \
# 0                                                    No
# 1                                                    No
# 2                                                   Yes
# 3                                                    No
# 4                                                    No
# ...                                                 ...
# 1248                                                Yes
# 1249                                                 No
# 1250                                                 No
# 1251                                                 No
# 1252                                                 No
#
#      Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1248                                                NaN
# 1249                                                NaN
# 1250                                                NaN
# 1251                                                NaN
# 1252                                               30.0
#
#      Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1248                                                NaN
# 1249                                                  0
# 1250                                                NaN
# 1251                                                  0
# 1252                                                600
#
# [1253 rows x 23 columns]

# %%
df.rename(columns = {'Yearly brutto salary (without bonus and stocks) in EUR':'Annual Salary in EUR'}, inplace = True)

# %%
df_new = df.loc[df['Position '].isin(['Data Analyst', 'Data Engineer', 'Data Scientist'])]
df_new
# Out:
#                 Timestamp   Age  Gender     City       Position   \
# 10    24/11/2020 11:18:06  32.0  Female  Hamburg   Data Engineer
# 35    24/11/2020 11:28:14  33.0    Male   Berlin  Data Scientist
# 66    24/11/2020 11:38:15  32.0    Male   Berlin  Data Scientist
# 68    24/11/2020 11:39:21  48.0    Male   London   Data Engineer
# 79    24/11/2020 11:44:02  26.0  Female   Munich  Data Scientist
# ...                   ...   ...     ...      ...             ...
# 1168  17/12/2020 10:28:18  40.0    Male   Berlin   Data Engineer
# 1186  21/12/2020 23:41:56  38.0    Male   Berlin  Data Scientist
# 1211  29/12/2020 23:57:42  29.0    Male   Munich  Data Scientist
# 1239  13/01/2021 23:42:49  38.0    Male   Munich    Data Analyst
# 1240  14/01/2021 01:14:58  31.0  Female   Berlin  Data Scientist
#
#      Total years of experience Years of experience in Germany Seniority level  \
# 10                           2                              2          Junior
# 35                           5                              4            Lead
# 66                          10                             10            Head
# 68                          23                              0             NaN
# 79                           6                              2          Middle
# ...                        ...                            ...             ...
# 1168                        14                              0          Middle
# 1186                         6                              3            Lead
# 1211                         6                              5          Middle
# 1239                        16                              4          Senior
# 1240                         4                              3          Middle
#
#      Your main technology / programming language  \
# 10                 Aws Hadoop Postgre Typescript
# 35                                        Python
# 66                                           NaN
# 68                         Google Cloud Platform
# 79                                        python
# ...                                          ...
# 1168                            BI, DWH, ETL/ELT
# 1186                                      Python
# 1211                                         SQL
# 1239                                         NaN
# 1240                                       spark
#
#      Other technologies/programming languages you use often  ...  \
# 10    Python, Kotlin, Javascript / Typescript, SQL, AWS      ...
# 35                      Python, R, Google Cloud, Docker      ...
# 66                                                  NaN      ...
# 68                  Python, SQL, Go, Google Cloud, bash      ...
# 79                           Python, C/C++, SQL, Docker      ...
# ...                                                 ...      ...
# 1168  Python, SQL, MS SQL Stack, Oracle, Informatica...      ...
# 1186                                             R, AWS      ...
# 1211                                             Python      ...
# 1239                                                 Bi      ...
# 1240                                   Python, SQL, AWS      ...
#
#       Annual bonus+stocks one year ago. Only answer if staying in same country  \
# 10                                                  NaN
# 35                                                 4000
# 66                                                15000
# 68                                                  NaN
# 79                                                60000
# ...                                                 ...
# 1168                                                NaN
# 1186                                             180000
# 1211                                              15000
# 1239                                             105000
# 1240                                                NaN
#
#      Number of vacation days   Employment status   Сontract duration  \
# 10                        30  Full-time employee  Unlimited contract
# 35                        24  Full-time employee  Unlimited contract
# 66                        30  Full-time employee  Unlimited contract
# 68                       NaN    Company Director  Temporary contract
# 79                        26  Full-time employee  Unlimited contract
# ...                      ...                 ...                 ...
# 1168                      24  Full-time employee  Unlimited contract
# 1186                      28  Full-time employee  Unlimited contract
# 1211                      28  Full-time employee  Unlimited contract
# 1239                      30  Full-time employee  Unlimited contract
# 1240                      30                 NaN  Unlimited contract
#
#      Main language at work Company size         Company type  \
# 10                  German     101-1000  Consulting / Agency
# 35                 English        1000+              Product
# 66                 English        1000+  Consulting / Agency
# 68                 English     up to 10         Personal Ltd
# 79                 English        1000+              Product
# ...                    ...          ...                  ...
# 1168               English     101-1000              Product
# 1186               English        1000+              Product
# 1211               English        1000+              Product
# 1239               English        1000+              Product
# 1240               English        1000+              Product
#
#      Have you lost your job due to the coronavirus outbreak?  \
# 10                                                   No
# 35                                                   No
# 66                                                   No
# 68                                                  Yes
# 79                                                   No
# ...                                                 ...
# 1168                                                 No
# 1186                                                 No
# 1211                                                 No
# 1239                                                 No
# 1240                                                 No
#
#      Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week  \
# 10                                                  NaN
# 35                                                  0.0
# 66                                                  NaN
# 68                                                  NaN
# 79                                                  NaN
# ...                                                 ...
# 1168                                                NaN
# 1186                                                NaN
# 1211                                                NaN
# 1239                                                NaN
# 1240                                                NaN
#
#      Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR
# 10                                                  NaN
# 35                                                    1
# 66                                                  NaN
# 68                                                  NaN
# 79                                                  NaN
# ...                                                 ...
# 1168                                                NaN
# 1186                                                NaN
# 1211                                                300
# 1239                                               1000
# 1240                                                500
#
# [143 rows x 23 columns]

# %%
plt.subplots(figsize=(15, 7.5), dpi =200)
sns.set(style = "white")

sns.boxplot(data= df_new, x= 'Position ', y= 'Annual Salary in EUR',hue = 'Gender',linewidth=2.5, fliersize=0)
sns.stripplot(data= df_new, x= 'Position ', y= 'Annual Salary in EUR', hue ='Gender')
plt.show()

# %%
plt.subplots(figsize=(15, 7.5), dpi =200)
sns.set(style = "white")

sns.boxplot(data= df_new, x= 'Position ', y= 'Annual Salary in EUR',hue = 'Seniority level')
plt.show()

# %%
plt.subplots(figsize=(15, 7.5), dpi =200)
sns.set(style = "white")
pal = sns.color_palette('Paired')


sns.boxplot(data= df_new, x= 'Position ', y= 'Annual Salary in EUR',hue = 'Gender',linewidth=2.5, fliersize=0, palette = pal)
sns.stripplot(data= df_new, x= 'Position ', y= 'Annual Salary in EUR', hue ='Gender', palette = pal)
plt.show()

# %%
plt.subplots(figsize=(15, 7.5), dpi =200)
sns.set(style = "white")
pal = my_pal = {"Female": "g", "Male": "b"}


sns.boxplot(data= df_new, x= 'Position ', y= 'Annual Salary in EUR',hue = 'Gender',linewidth=2.5, fliersize=0, palette = pal)
sns.stripplot(data= df_new, x= 'Position ', y= 'Annual Salary in EUR', hue ='Gender', palette = pal)
plt.show()

# %%
# When you start digging into the parameters, it's a good idea
# to explicitly initialize the figure and get the figure and
# axes handles
fig, ax = plt.subplots(figsize=(15, 7.5), dpi =200)

# First, we'll pick some nicer colors for the Male and Female.
# I got these colors from the color picker online.
dark_blue='#161bb2'
dark_pink='#b2165c'
pal = {'Male': dark_blue, 'Female': dark_pink}

# Here, we set up some properties for the boxplot parts.I borrowed this from stackoverflow
boxprops = {'edgecolor': 'k', 'linewidth': 2, 'facecolor': 'w'}
lineprops = {'color': 'k', 'linewidth': 2}

# Set up some general kwargs that we'll use in both the stripplot and boxplot
# Note that you can change the order of hue variables here.
kwargs = {'palette': pal, 'hue_order': ['Male', 'Female']}

# The boxplot kwargs get passed to matplotlib's boxplot function.
# Note how we can re-use our lineprops dict to make sure all the lines
# match. You could also edit each line type (e.g. whiskers, caps, etc)
# separately.
boxplot_kwargs = dict({'boxprops': boxprops, 'medianprops': lineprops,
                       'whiskerprops': lineprops, 'capprops': lineprops,
                       'width': 0.75},
                      **kwargs)
stripplot_kwargs = dict({'linewidth': 0.6, 'size': 6, 'alpha': 0.7},
                        **kwargs)

# And we can plot just like last time
sns.boxplot(data= df_new, x= 'Position ', y= 'Annual Salary in EUR',hue = 'Gender', ax=ax,
    fliersize=0, **boxplot_kwargs)
sns.stripplot(data= df_new, x= 'Position ', y= 'Annual Salary in EUR',hue = 'Gender', ax=ax,
    dodge=True, jitter=0.2, **stripplot_kwargs)
# Out:
# <AxesSubplot:xlabel='Position ', ylabel='Annual Salary in EUR'>

# %%
#Remove the spines
ax.spines()

pal = {'Male': dark_blue, 'Female': dark_pink}

# Set up another palette for the boxplots, with slightly lighter shades
light_blue = '#1698b2'
light_pink = '#ad16b2'
face_pal = {'Male': light_blue, 'Female': light_pink}

hue_order = ['Male', 'Female']

# You have to  remove the 'facecolor': 'w' property here,
# or else the palette gets overrided
boxprops = {'edgecolor': 'k', 'linewidth': 2}
lineprops = {'color': 'k', 'linewidth': 2}

boxplot_kwargs = {'boxprops': boxprops, 'medianprops': lineprops,
                  'whiskerprops': lineprops, 'capprops': lineprops,
                  'width': 0.75, 'palette': face_pal,
                  'hue_order': hue_order}

stripplot_kwargs = {'linewidth': 0.6, 'size': 6, 'alpha': 0.7,
                    'palette': pal, 'hue_order': hue_order}


# And we can plot just like last time
fig, ax = plt.subplots(figsize=(15, 7.5), dpi =200)

sns.boxplot(data= df_new, x= 'Position ', y= 'Annual Salary in EUR',hue = 'Gender', ax=ax,
    fliersize=0, **boxplot_kwargs)
sns.stripplot(data= df_new, x= 'Position ', y= 'Annual Salary in EUR',hue = 'Gender', ax=ax,
    dodge=True, jitter=0.2, **stripplot_kwargs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-f1fa3b893b12> in <module>
#       1 #Remove the spines
# ----> 2 ax.spines()
#       3
#       4 pal = {'Male': dark_blue, 'Female': dark_pink}
#       5
#
# TypeError: 'collections.OrderedDict' object is not callable
